# %%
# import packages
import warnings
warnings.filterwarnings("ignore")

import pandas as pd
pd.options.display.max_rows = 999
pd.set_option("expand_frame_repr", True)

import matplotlib.pyplot as plt

# graph networks
import networkx as nx 

# open street map data
import osmnx as ox

from shapely.geometry import Point

#Import Seaborn as sns
import seaborn as sns

#Numpy for scoring 
import numpy as np
# Out:
# /Users/philinesophie/opt/anaconda3/lib/python3.8/site-packages/ipykernel/ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
#switch off warnings
def fxn():
    warnings.warn("deprecated", DeprecationWarning)

with warnings.catch_warnings():
    warnings.simplefilter("ignore")
    fxn()

# %% [markdown]
# ## Graph of Düsseldorf as a reference for the project

# %%
# get graph for Düsseldorf
place = 'Düsseldorf, Germany'
network_type = 'walk'
#G = ox.graph_from_place(place, network_type=network_type)
G = ox.graph_from_address(place, network_type=network_type, dist=3000)

# %%
#show graph # colour a bit to light 
ox.plot_graph(G, figsize=(10, 10), show=False, close=False)
# Out:
# /Users/philinesophie/opt/anaconda3/lib/python3.8/site-packages/ipykernel/ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# (<Figure size 720x720 with 1 Axes>, <AxesSubplot:>)

# %% [markdown]
# ## Points of interests in regarding area

# %%
# get list of places in Düsseldorf
# https://wiki.openstreetmap.org/wiki/Map_features#Transportation

tags = {'amenity':True, 'landuse':['retail','commercial','transportation', 'education']} 
places_df = ox.geometries.geometries_from_address(place, tags=tags)
places_df = places_df.reset_index(level=[0,1])
places_df
# Out:
#      element_type      osmid           amenity  check_date  source  \
# 0            node  240270700         telephone  2021-03-12  survey
# 1            node  240270717  parking_entrance         NaN     NaN
# 2            node  240270723              cafe         NaN  survey
# 3            node  240270745               pub         NaN  survey
# 4            node  240270787          post_box         NaN     NaN
# ...           ...        ...               ...         ...     ...
# 1547     relation       8607            police         NaN     NaN
# 1548     relation    1965896   public_building         NaN     NaN
# 1549     relation    4785870            school         NaN     NaN
# 1550     relation    6390053               NaN         NaN     NaN
# 1551     relation   10542133               NaN         NaN     NaN
#
#                                                geometry  fee  \
# 0                              POINT (6.78976 51.22756)  NaN
# 1                              POINT (6.78733 51.22615)  yes
# 2                              POINT (6.78746 51.22174)  NaN
# 3                              POINT (6.78796 51.22126)  NaN
# 4                              POINT (6.78729 51.21945)  NaN
# ...                                                 ...  ...
# 1547  POLYGON ((6.76765 51.21569, 6.76763 51.21567, ...  NaN
# 1548  POLYGON ((6.76966 51.22234, 6.76976 51.22248, ...  NaN
# 1549  MULTIPOLYGON (((6.78731 51.23520, 6.78733 51.2...  NaN
# 1550  POLYGON ((6.77846 51.22558, 6.77726 51.22556, ...  NaN
# 1551  POLYGON ((6.77683 51.22302, 6.77697 51.22296, ...  NaN
#
#                           name       parking wheelchair  ...  \
# 0                          NaN           NaN        NaN  ...
# 1            Karstadt Parkhaus  multi-storey        yes  ...
# 2            Zaxopondeiva Cafe           NaN    limited  ...
# 3        Wilma Next Generation           NaN    limited  ...
# 4                          NaN           NaN        NaN  ...
# ...                        ...           ...        ...  ...
# 1547          Polizeipräsidium           NaN        yes  ...
# 1548               Palais Spee           NaN        NaN  ...
# 1549  Matthias-Claudius-Schule           NaN        NaN  ...
# 1550                       NaN           NaN        NaN  ...
# 1551                       NaN           NaN        NaN  ...
#
#      maxstay:conditional construction:end_date construction:start_date  \
# 0                    NaN                   NaN                     NaN
# 1                    NaN                   NaN                     NaN
# 2                    NaN                   NaN                     NaN
# 3                    NaN                   NaN                     NaN
# 4                    NaN                   NaN                     NaN
# ...                  ...                   ...                     ...
# 1547                 NaN                  1932                    1929
# 1548                 NaN                   NaN                     NaN
# 1549                 NaN                   NaN                     NaN
# 1550                 NaN                   NaN                     NaN
# 1551                 NaN                   NaN                     NaN
#
#      quitting_hours building:use:residential building:part room  \
# 0               NaN                      NaN           NaN  NaN
# 1               NaN                      NaN           NaN  NaN
# 2               NaN                      NaN           NaN  NaN
# 3               NaN                      NaN           NaN  NaN
# 4               NaN                      NaN           NaN  NaN
# ...             ...                      ...           ...  ...
# 1547            NaN                      NaN           NaN  NaN
# 1548            NaN                      NaN           NaN  NaN
# 1549            NaN                      NaN           NaN  NaN
# 1550            NaN                      NaN           NaN  NaN
# 1551            NaN                      NaN           NaN  NaN
#
#      parking:orientation                                      ways  \
# 0                    NaN                                       NaN
# 1                    NaN                                       NaN
# 2                    NaN                                       NaN
# 3                    NaN                                       NaN
# 4                    NaN                                       NaN
# ...                  ...                                       ...
# 1547                 NaN  [23442872, 23442873, 23442874, 23442875]
# 1548                 NaN                    [145266539, 145266543]
# 1549                 NaN                    [334291400, 338471626]
# 1550                 NaN                               [142759466]
# 1551                 NaN                    [523064879, 760846105]
#
#      building:roof:shape
# 0                    NaN
# 1                    NaN
# 2                    NaN
# 3                    NaN
# 4                    NaN
# ...                  ...
# 1547                flat
# 1548                 NaN
# 1549                 NaN
# 1550                 NaN
# 1551                 NaN
#
# [1552 rows x 289 columns]

# %%
# filter dataframe
places_filt_df = places_df[places_df["element_type"]=="node"]
places_filt_df
# Out:
# /Users/philinesophie/opt/anaconda3/lib/python3.8/site-packages/ipykernel/ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#      element_type       osmid           amenity  check_date  source  \
# 0            node   240270700         telephone  2021-03-12  survey
# 1            node   240270717  parking_entrance         NaN     NaN
# 2            node   240270723              cafe         NaN  survey
# 3            node   240270745               pub         NaN  survey
# 4            node   240270787          post_box         NaN     NaN
# ...           ...         ...               ...         ...     ...
# 1377         node  9073199797   vending_machine         NaN     NaN
# 1378         node  9073200627   bicycle_parking         NaN     NaN
# 1379         node  9073201970      waste_basket         NaN     NaN
# 1380         node  9073202692   vending_machine         NaN     NaN
# 1381         node  9073203128             bench         NaN     NaN
#
#                       geometry  fee                   name       parking  \
# 0     POINT (6.78976 51.22756)  NaN                    NaN           NaN
# 1     POINT (6.78733 51.22615)  yes      Karstadt Parkhaus  multi-storey
# 2     POINT (6.78746 51.22174)  NaN      Zaxopondeiva Cafe           NaN
# 3     POINT (6.78796 51.22126)  NaN  Wilma Next Generation           NaN
# 4     POINT (6.78729 51.21945)  NaN                    NaN           NaN
# ...                        ...  ...                    ...           ...
# 1377  POINT (6.78202 51.22308)  NaN                    NaN           NaN
# 1378  POINT (6.78355 51.22140)  NaN                    NaN           NaN
# 1379  POINT (6.78974 51.22079)  NaN                    NaN           NaN
# 1380  POINT (6.78131 51.22318)  NaN                    NaN           NaN
# 1381  POINT (6.78593 51.22286)  NaN                    NaN           NaN
#
#      wheelchair  ... maxstay:conditional construction:end_date  \
# 0           NaN  ...                 NaN                   NaN
# 1           yes  ...                 NaN                   NaN
# 2       limited  ...                 NaN                   NaN
# 3       limited  ...                 NaN                   NaN
# 4           NaN  ...                 NaN                   NaN
# ...         ...  ...                 ...                   ...
# 1377        NaN  ...                 NaN                   NaN
# 1378        NaN  ...                 NaN                   NaN
# 1379        NaN  ...                 NaN                   NaN
# 1380        NaN  ...                 NaN                   NaN
# 1381        NaN  ...                 NaN                   NaN
#
#      construction:start_date quitting_hours building:use:residential  \
# 0                        NaN            NaN                      NaN
# 1                        NaN            NaN                      NaN
# 2                        NaN            NaN                      NaN
# 3                        NaN            NaN                      NaN
# 4                        NaN            NaN                      NaN
# ...                      ...            ...                      ...
# 1377                     NaN            NaN                      NaN
# 1378                     NaN            NaN                      NaN
# 1379                     NaN            NaN                      NaN
# 1380                     NaN            NaN                      NaN
# 1381                     NaN            NaN                      NaN
#
#      building:part room parking:orientation ways building:roof:shape
# 0              NaN  NaN                 NaN  NaN                 NaN
# 1              NaN  NaN                 NaN  NaN                 NaN
# 2              NaN  NaN                 NaN  NaN                 NaN
# 3              NaN  NaN                 NaN  NaN                 NaN
# 4              NaN  NaN                 NaN  NaN                 NaN
# ...            ...  ...                 ...  ...                 ...
# 1377           NaN  NaN                 NaN  NaN                 NaN
# 1378           NaN  NaN                 NaN  NaN                 NaN
# 1379           NaN  NaN                 NaN  NaN                 NaN
# 1380           NaN  NaN                 NaN  NaN                 NaN
# 1381           NaN  NaN                 NaN  NaN                 NaN
#
# [1382 rows x 289 columns]

# %%
# list all types of amenities (top 25 by count) to choose which amenity should be used as a criteria for Project
places_filt_df[["amenity"]].value_counts()
# Out:
# /Users/philinesophie/opt/anaconda3/lib/python3.8/site-packages/ipykernel/ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# amenity
# restaurant            200
# bench                 192
# waste_basket          117
# bicycle_parking       106
# vending_machine       101
# cafe                   71
# pub                    70
# fast_food              46
# recycling              38
# post_box               37
# bar                    29
# telephone              29
# atm                    29
# parking_entrance       29
# taxi                   25
# bank                   23
# doctors                21
# nightclub              21
# pharmacy               18
# parking                17
# toilets                17
# theatre                12
# fountain               12
# kindergarten           10
# clock                  10
# shelter                 9
# library                 8
# charging_station        8
# ice_cream               8
# dentist                 7
# motorcycle_parking      7
# post_office             5
# cinema                  4
# arts_centre             4
# social_facility         4
# police                  3
# ticket_validator        3
# college                 2
# studio                  2
# social_centre           2
# car_rental              2
# public_bookcase         2
# financial_advice        2
# fire_station            2
# place_of_worship        2
# drinking_water          2
# gambling                2
# community_centre        1
# concert_hall            1
# courthouse              1
# public_bath             1
# coworking_space         1
# car_wash                1
# music_school            1
# biergarten              1
# stock_exchange          1
# stripclub               1
# driving_school          1
# language_school         1
# dtype: int64

# %%
# define list of important places
important_places_list = [
    "bar", "doctors", "kindergarten"
]

# %%
# filter by important places
places_filt_df = places_filt_df[places_filt_df["amenity"].isin(important_places_list)]
places_filt_df.reset_index(drop=True, inplace=True)
places_filt_df
# Out:
#    element_type       osmid       amenity check_date  source  \
# 0          node   240272663           bar        NaN     NaN
# 1          node   240272821       doctors        NaN     NaN
# 2          node   314318860           bar        NaN     NaN
# 3          node   719743593           bar        NaN     NaN
# 4          node   866734195           bar        NaN     NaN
# 5          node   935548781  kindergarten        NaN     NaN
# 6          node   935548792  kindergarten        NaN     NaN
# 7          node   935559068  kindergarten        NaN     NaN
# 8          node   935570415  kindergarten        NaN     NaN
# 9          node   937151140  kindergarten        NaN     NaN
# 10         node  1054204768  kindergarten        NaN     NaN
# 11         node  1054204893  kindergarten        NaN     NaN
# 12         node  1191234002  kindergarten        NaN     NaN
# 13         node  1570459649           bar        NaN     NaN
# 14         node  1572056103           bar        NaN     NaN
# 15         node  1577234947           bar        NaN     NaN
# 16         node  1577235526           bar        NaN     NaN
# 17         node  1577236620           bar        NaN     NaN
# 18         node  1640116467           bar        NaN     NaN
# 19         node  1843764000           bar        NaN     NaN
# 20         node  2370921949  kindergarten        NaN     NaN
# 21         node  2397714583           bar        NaN  survey
# 22         node  2673266821       doctors        NaN     NaN
# 23         node  2694400071       doctors        NaN     NaN
# 24         node  3016215779       doctors        NaN     NaN
# 25         node  3230356005           bar        NaN     NaN
# 26         node  3789325913           bar        NaN     NaN
# 27         node  3914948967       doctors        NaN     NaN
# 28         node  4355575289       doctors        NaN     NaN
# 29         node  4372497990           bar        NaN     NaN
# 30         node  4497525390           bar        NaN     NaN
# 31         node  4733186917       doctors        NaN     NaN
# 32         node  4760466363       doctors        NaN     NaN
# 33         node  4767958199       doctors        NaN     NaN
# 34         node  4773474808           bar        NaN     NaN
# 35         node  4778413091           bar        NaN     NaN
# 36         node  4778494773           bar        NaN     NaN
# 37         node  4810454569       doctors        NaN     NaN
# 38         node  5237243182           bar        NaN     NaN
# 39         node  5260880028  kindergarten        NaN     NaN
# 40         node  5260997376       doctors        NaN     NaN
# 41         node  5315383765           bar        NaN     NaN
# 42         node  5427555630       doctors        NaN     NaN
# 43         node  5427555631       doctors        NaN     NaN
# 44         node  5485467167       doctors        NaN     NaN
# 45         node  5570743621           bar        NaN     NaN
# 46         node  5897337427           bar        NaN     NaN
# 47         node  5968504289       doctors        NaN     NaN
# 48         node  6105743437           bar        NaN     NaN
# 49         node  6259386723           bar        NaN     NaN
# 50         node  6542850396       doctors        NaN     NaN
# 51         node  6775550061       doctors        NaN  survey
# 52         node  7035374391       doctors        NaN  survey
# 53         node  7170205185           bar        NaN     NaN
# 54         node  7172727585           bar        NaN     NaN
# 55         node  7255438836       doctors        NaN     NaN
# 56         node  7598059933           bar        NaN     NaN
# 57         node  8544871305       doctors        NaN     NaN
# 58         node  8848298797       doctors        NaN     NaN
# 59         node  9053876294           bar        NaN     NaN
#
#                     geometry  fee  \
# 0   POINT (6.78655 51.22208)  NaN
# 1   POINT (6.78351 51.22126)  NaN
# 2   POINT (6.77363 51.22622)  NaN
# 3   POINT (6.77334 51.22818)  NaN
# 4   POINT (6.77556 51.22761)  NaN
# 5   POINT (6.77250 51.22850)  NaN
# 6   POINT (6.77423 51.22673)  NaN
# 7   POINT (6.78432 51.22077)  NaN
# 8   POINT (6.79019 51.22534)  NaN
# 9   POINT (6.78197 51.23422)  NaN
# 10  POINT (6.78720 51.22335)  NaN
# 11  POINT (6.78709 51.22318)  NaN
# 12  POINT (6.77209 51.21925)  NaN
# 13  POINT (6.77164 51.22455)  NaN
# 14  POINT (6.77280 51.22681)  NaN
# 15  POINT (6.77301 51.22601)  NaN
# 16  POINT (6.77508 51.22936)  NaN
# 17  POINT (6.77545 51.22942)  NaN
# 18  POINT (6.77239 51.22658)  NaN
# 19  POINT (6.78749 51.21859)  NaN
# 20  POINT (6.78502 51.22397)  NaN
# 21  POINT (6.76478 51.21964)  NaN
# 22  POINT (6.78941 51.21677)  NaN
# 23  POINT (6.78711 51.22808)  NaN
# 24  POINT (6.78327 51.22080)  NaN
# 25  POINT (6.77332 51.22822)  NaN
# 26  POINT (6.77167 51.22491)  NaN
# 27  POINT (6.78626 51.22521)  NaN
# 28  POINT (6.78155 51.21921)  NaN
# 29  POINT (6.77547 51.23013)  NaN
# 30  POINT (6.77052 51.22665)  NaN
# 31  POINT (6.78812 51.22530)  NaN
# 32  POINT (6.77660 51.21773)  NaN
# 33  POINT (6.77589 51.21832)  NaN
# 34  POINT (6.77034 51.22502)  NaN
# 35  POINT (6.78141 51.22696)  NaN
# 36  POINT (6.77831 51.22580)  NaN
# 37  POINT (6.78145 51.22138)  NaN
# 38  POINT (6.77239 51.22664)  NaN
# 39  POINT (6.78532 51.23187)  NaN
# 40  POINT (6.78346 51.22125)  NaN
# 41  POINT (6.77497 51.22824)  NaN
# 42  POINT (6.78528 51.22343)  NaN
# 43  POINT (6.78522 51.22346)  NaN
# 44  POINT (6.78633 51.22854)  NaN
# 45  POINT (6.78091 51.21764)  NaN
# 46  POINT (6.79038 51.23377)  NaN
# 47  POINT (6.78696 51.22786)  NaN
# 48  POINT (6.77866 51.23306)  NaN
# 49  POINT (6.77594 51.22949)  NaN
# 50  POINT (6.78234 51.21827)  NaN
# 51  POINT (6.78257 51.22086)  NaN
# 52  POINT (6.77963 51.22579)  NaN
# 53  POINT (6.78788 51.21826)  NaN
# 54  POINT (6.78586 51.21877)  NaN
# 55  POINT (6.78924 51.22521)  NaN
# 56  POINT (6.77549 51.22697)  NaN
# 57  POINT (6.78372 51.23112)  NaN
# 58  POINT (6.78760 51.22861)  NaN
# 59  POINT (6.77256 51.22507)  NaN
#
#                                                 name parking wheelchair  ...  \
# 0                                             Exodus     NaN    limited  ...
# 1                      Kiefer- und Gesichtschirurgie     NaN        NaN  ...
# 2                                        Twenty Four     NaN    limited  ...
# 3                                    La Guantanamera     NaN         no  ...
# 4                                 Salon des Amateurs     NaN         no  ...
# 5            Tageseinrichtung für Kinder - Altestadt     NaN        NaN  ...
# 6           Evangelische Tageseinrichtung für Kinder     NaN    limited  ...
# 7                           Fröbelscher Kindergarten     NaN        NaN  ...
# 8   Tageseinrichtung für Kinder – Hohenzollernstraße     NaN        NaN  ...
# 9          Tageseinrichtung für Kinder - Sternstraße     NaN        NaN  ...
# 10                                   Kita-TuB-Zwerge     NaN        NaN  ...
# 11                              KiTa Kleiner Elefant     NaN        NaN  ...
# 12             Kindertagesstätte Pünktchen und Anton     NaN        NaN  ...
# 13                                            Medusa     NaN         no  ...
# 14                                      Elephant Bar     NaN         no  ...
# 15                                         Chill Out     NaN    limited  ...
# 16                                      Köhlerliesel     NaN    limited  ...
# 17                         Schlösser Quartier Bohème     NaN    limited  ...
# 18                                        #3 hashtag     NaN        NaN  ...
# 19                                         Ellington     NaN        NaN  ...
# 20        Vorkindergarten Froschkönig – Marienstraße     NaN        NaN  ...
# 21                                     Rhein Rondell     NaN        NaN  ...
# 22                        Advitam Gesundheitszentrum     NaN        yes  ...
# 23                              Urologie am Malkasen     NaN        NaN  ...
# 24                               ahearn Chiropractic     NaN        yes  ...
# 25                                          Papidoux     NaN         no  ...
# 26                                           Stickum     NaN        yes  ...
# 27                 Neurologie Schulte/Richter/Capito     NaN        yes  ...
# 28                                         Ärztehaus     NaN        yes  ...
# 29                                 Weinbar Eiskeller     NaN        yes  ...
# 30                                   Cocktailbar 112     NaN        yes  ...
# 31                               Ärztehaus Oststraße     NaN        yes  ...
# 32                                  Facharzt Zentrum     NaN        NaN  ...
# 33                      3T MRT Radiologie Düsseldorf     NaN        NaN  ...
# 34                                               #10     NaN        NaN  ...
# 35                            Sansibar by Breuninger     NaN        NaN  ...
# 36                                    The Attic Kö 1     NaN        NaN  ...
# 37                            Physiotherapie fidelis     NaN        yes  ...
# 38                                             Gob's     NaN        NaN  ...
# 39                                    Storchennester     NaN        NaN  ...
# 40                                  Dr. Hartz-Schütt     NaN        NaN  ...
# 41                                      20° Restobar     NaN        yes  ...
# 42                            Dr. med. Jürgen Hessel     NaN        NaN  ...
# 43                            Dr. med. Annette Klose     NaN        NaN  ...
# 44                     Gemeinschaftspraxis Hautärzte     NaN        NaN  ...
# 45                                      bar studio 1     NaN        NaN  ...
# 46                                    Cafe Bar Zogel     NaN        NaN  ...
# 47          Gemeinschaftspraxis Schaden, Diabetologe     NaN        yes  ...
# 48                                     Purple Lounge     NaN        NaN  ...
# 49                                        Retematäng     NaN        NaN  ...
# 50                                  Dr. Dirk Stolley     NaN        NaN  ...
# 51                              Therapieteam Nentwig     NaN        NaN  ...
# 52                                              Kö12     NaN        NaN  ...
# 53                                       Scheuren 12     NaN        NaN  ...
# 54                                         Alchemist     NaN        NaN  ...
# 55                           Neurozentrum Düsseldorf     NaN        NaN  ...
# 56                                     The Oak´s Bar     NaN        NaN  ...
# 57                               Dr. Michael Schäfer     NaN         no  ...
# 58                             Hausarzt am Hofgarten     NaN        NaN  ...
# 59                                       Et Kabüffke     NaN        NaN  ...
#
#    maxstay:conditional construction:end_date construction:start_date  \
# 0                  NaN                   NaN                     NaN
# 1                  NaN                   NaN                     NaN
# 2                  NaN                   NaN                     NaN
# 3                  NaN                   NaN                     NaN
# 4                  NaN                   NaN                     NaN
# 5                  NaN                   NaN                     NaN
# 6                  NaN                   NaN                     NaN
# 7                  NaN                   NaN                     NaN
# 8                  NaN                   NaN                     NaN
# 9                  NaN                   NaN                     NaN
# 10                 NaN                   NaN                     NaN
# 11                 NaN                   NaN                     NaN
# 12                 NaN                   NaN                     NaN
# 13                 NaN                   NaN                     NaN
# 14                 NaN                   NaN                     NaN
# 15                 NaN                   NaN                     NaN
# 16                 NaN                   NaN                     NaN
# 17                 NaN                   NaN                     NaN
# 18                 NaN                   NaN                     NaN
# 19                 NaN                   NaN                     NaN
# 20                 NaN                   NaN                     NaN
# 21                 NaN                   NaN                     NaN
# 22                 NaN                   NaN                     NaN
# 23                 NaN                   NaN                     NaN
# 24                 NaN                   NaN                     NaN
# 25                 NaN                   NaN                     NaN
# 26                 NaN                   NaN                     NaN
# 27                 NaN                   NaN                     NaN
# 28                 NaN                   NaN                     NaN
# 29                 NaN                   NaN                     NaN
# 30                 NaN                   NaN                     NaN
# 31                 NaN                   NaN                     NaN
# 3                                    La Guantanamera
# 4                                 Salon des Amateurs
# 5            Tageseinrichtung für Kinder - Altestadt
# 6           Evangelische Tageseinrichtung für Kinder
# 7                           Fröbelscher Kindergarten
# 8   Tageseinrichtung für Kinder – Hohenzollernstraße
# 9          Tageseinrichtung für Kinder - Sternstraße
# 10                                   Kita-TuB-Zwerge
# 11                              KiTa Kleiner Elefant
# 12             Kindertagesstätte Pünktchen und Anton
# 13                                            Medusa
# 14                                      Elephant Bar
# 15                                         Chill Out
# 16                                      Köhlerliesel
# 17                         Schlösser Quartier Bohème
# 18                                        #3 hashtag
# 19                                         Ellington
# 20        Vorkindergarten Froschkönig – Marienstraße
# 21                                     Rhein Rondell
# 22                        Advitam Gesundheitszentrum
# 23                              Urologie am Malkasen
# 24                               ahearn Chiropractic
# 25                                          Papidoux
# 26                                           Stickum
# 27                 Neurologie Schulte/Richter/Capito
# 28                                         Ärztehaus
# 29                                 Weinbar Eiskeller
# 30                                   Cocktailbar 112
# 31                               Ärztehaus Oststraße
# 32                                  Facharzt Zentrum
# 33                      3T MRT Radiologie Düsseldorf
# 34                                               #10
# 35                            Sansibar by Breuninger
# 36                                    The Attic Kö 1
# 37                            Physiotherapie fidelis
# 38                                             Gob's
# 39                                    Storchennester
# 40                                  Dr. Hartz-Schütt
# 41                                      20° Restobar
# 42                            Dr. med. Jürgen Hessel
# 43                            Dr. med. Annette Klose
# 44                     Gemeinschaftspraxis Hautärzte
# 45                                      bar studio 1
# 46                                    Cafe Bar Zogel
# 47          Gemeinschaftspraxis Schaden, Diabetologe
# 48                                     Purple Lounge
# 49                                        Retematäng
# 50                                  Dr. Dirk Stolley
# 51                              Therapieteam Nentwig
# 52                                              Kö12
# 53                                       Scheuren 12
# 54                                         Alchemist
# 55                           Neurozentrum Düsseldorf
# 56                                     The Oak´s Bar
# 57                               Dr. Michael Schäfer
# 58                             Hausarzt am Hofgarten
# 59                                       Et Kabüffke

# %% [markdown]
# ## Get data out of graph

# %%
# turn Graph G into nodes to check distance
nodes, edges = ox.graph_to_gdfs(G)
nodes.head()
# Out:
#                   y         x  street_count highway  ref  \
# osmid
# 5269985   51.198483  6.736442             3     NaN  NaN
# 5270135   51.206686  6.756832             3     NaN  NaN
# 5278499   51.215004  6.761004             1     NaN  NaN
# 21556382  51.221888  6.791452             4     NaN  NaN
# 21556383  51.220719  6.789764             4     NaN  NaN
#
#                           geometry
# osmid
# 5269985   POINT (6.73644 51.19848)
# 5270135   POINT (6.75683 51.20669)
# 5278499   POINT (6.76100 51.21500)
# 21556382  POINT (6.79145 51.22189)
# 21556383  POINT (6.78976 51.22072)

# %%
#calculate length of nodes to check to get an idea of Data
nodes=nodes.reset_index()
len(nodes)
# Out:
# /Users/philinesophie/opt/anaconda3/lib/python3.8/site-packages/ipykernel/ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# 16485

# %%
nodes.head()
# Out:
#       osmid          y         x  street_count highway  ref  \
# 0   5269985  51.198483  6.736442             3     NaN  NaN
# 1   5270135  51.206686  6.756832             3     NaN  NaN
# 2   5278499  51.215004  6.761004             1     NaN  NaN
# 3  21556382  51.221888  6.791452             4     NaN  NaN
# 4  21556383  51.220719  6.789764             4     NaN  NaN
#
#                    geometry
# 0  POINT (6.73644 51.19848)
# 1  POINT (6.75683 51.20669)
# 2  POINT (6.76100 51.21500)
# 3  POINT (6.79145 51.22189)
# 4  POINT (6.78976 51.22072)

# %%
#use a sample of the nodes to minimize calculation time
nodes_filt=nodes.sample(2000)
# Out:
# /Users/philinesophie/opt/anaconda3/lib/python3.8/site-packages/ipykernel/ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
nodes_filt=nodes_filt.reset_index()
nodes_filt.head()
# Out:
#    index       osmid          y         x  street_count   highway  ref  \
# 0   3521   570340208  51.216364  6.795076             3       NaN  NaN
# 1  15598  7773277816  51.239556  6.787060             3  crossing  NaN
# 2  15721  7896812003  51.201429  6.788670             3       NaN  NaN
# 3  15864  8047910987  51.222365  6.775603             1       NaN  NaN
# 4   9932  3165421586  51.202972  6.755473             1       NaN  NaN
#
#                    geometry
# 0  POINT (6.79508 51.21636)
# 1  POINT (6.78706 51.23956)
# 2  POINT (6.78867 51.20143)
# 3  POINT (6.77560 51.22237)
# 4  POINT (6.75547 51.20297)

# %%
# function to calculate distance and travel time between two points
def calc_dist_and_time(point_1, point_2):
    
    # find node on map based on coordinates
    point_1_temp = (point_1.y, point_1.x)
    point_1_node = ox.get_nearest_node(G, point_1_temp)

    point_2_temp = (point_1.y, point_2.x)
    point_2_node = ox.get_nearest_node(G, point_2_temp)
    
    # calculate distance between two nodes
    dist_m = nx.shortest_path_length(G, point_1_node, point_2_node, weight='length')
    
    # calculate travel time based on 4.5km/h
    time = round(dist_m*0.0133)
    
    # return
    return dist_m, time

# %%
# calculate and add distance to defined center point (e.g., Düsseldorf Hbf) # idea to fasten the calculation underneath
places_filt_df["distance_in_m"] = places_filt_df.apply(
    lambda row: 
    calc_dist_and_time(point_1, row["geometry"])[0], 
    axis=1)

places_filt_df["travel_time"] = places_filt_df.apply(
    lambda row: 
    calc_dist_and_time(point_1, row["geometry"])[1], 
    axis=1)

# %%
# %%time
# loop through list of places, calculate distance and time, and plot map and information
for i in range(0,len(nodes_filt)):  
    temp_df= pd.DataFrame()
    for j in range(0,len(places_filt_df)):
        point_1 = nodes_filt.at[i, "geometry"]
     
        
        point_2 = places_filt_df.at[j, "geometry"]
        amenity_2= places_filt_df.at[j, 'amenity']

        #print(f'point_1: {point_1}, point_2: {point_2}')
        
        meta_info2=calc_dist_and_time(point_1, point_2)
        #print(meta_info2)
        distance_m=meta_info2[0]
        distance_time=meta_info2[1]
        #temporäre Tabelle anlegen. Da sonst I wieder überschrieben wird
        temp_df.at[j,'minutes']=distance_time
        temp_df.at[j, 'amenity']=amenity_2
        
    places_grouped=temp_df.groupby(["amenity"]).agg({'minutes': 'min'})
    nodes_filt.at[i,'avg_minutes']=places_grouped['minutes'].mean()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <timed exec> in <module>
#
# <ipython-input-16-2eec20876212> in calc_dist_and_time(point_1, point_2)
#       7
#       8     point_2_temp = (point_1.y, point_2.x)
# ----> 9     point_2_node = ox.get_nearest_node(G, point_2_temp)
#      10
#      11     # calculate distance between two nodes
#
# ~/opt/anaconda3/lib/python3.8/site-packages/osmnx/distance.py in get_nearest_node(G, point, method, return_dist)
#     355     )
#     356     warnings.warn(msg)
# --> 357     nn, dist = nearest_nodes(G, X=[point[1]], Y=[point[0]], return_dist=True)
#     358     if return_dist:
#     359         return nn[0], dist[0]
#
# ~/opt/anaconda3/lib/python3.8/site-packages/osmnx/distance.py in nearest_nodes(G, X, Y, return_dist)
#     186     if np.isnan(X).any() or np.isnan(Y).any():  # pragma: no cover
#     187         raise ValueError("`X` and `Y` cannot contain nulls")
# --> 188     nodes = utils_graph.graph_to_gdfs(G, edges=False, node_geometry=False)[["x", "y"]]
#     189
#     190     if projection.is_projected(G.graph["crs"]):
#
# ~/opt/anaconda3/lib/python3.8/site-packages/osmnx/utils_graph.py in graph_to_gdfs(G, nodes, edges, node_geometry, fill_edge_geometry)
#      48             raise ValueError("graph contains no nodes")
#      49
# ---> 50         nodes, data = zip(*G.nodes(data=True))
#      51
#      52         if node_geometry:
#
# KeyboardInterrupt:

# %%
nodes_filt
# Out:
# /Users/philinesophie/opt/anaconda3/lib/python3.8/site-packages/ipykernel/ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#       index       osmid          y         x  street_count   highway  ref  \
# 0      3521   570340208  51.216364  6.795076             3       NaN  NaN
# 1     15598  7773277816  51.239556  6.787060             3  crossing  NaN
# 2     15721  7896812003  51.201429  6.788670             3       NaN  NaN
# 3     15864  8047910987  51.222365  6.775603             1       NaN  NaN
# 4      9932  3165421586  51.202972  6.755473             1       NaN  NaN
# ...     ...         ...        ...       ...           ...       ...  ...
# 1995   7954  1995330396  51.228287  6.799565             3       NaN  NaN
# 1996   1647   267768377  51.205168  6.802241             3       NaN  NaN
# 1997   1307   254147817  51.246451  6.809047             3       NaN  NaN
# 1998   3150   483385328  51.242463  6.766796             1       NaN  NaN
# 1999   3010   468463074  51.230662  6.786838             4       NaN  NaN
#
#                       geometry  avg_minutes
# 0     POINT (6.79508 51.21636)     6.000000
# 1     POINT (6.78706 51.23956)     0.000000
# 2     POINT (6.78867 51.20143)     1.333333
# 3     POINT (6.77560 51.22237)     1.666667
# 4     POINT (6.75547 51.20297)    46.333333
# ...                        ...          ...
# 1995  POINT (6.79956 51.22829)          NaN
# 1996  POINT (6.80224 51.20517)          NaN
# 1997  POINT (6.80905 51.24645)          NaN
# 1998  POINT (6.76680 51.24246)          NaN
# 1999  POINT (6.78684 51.23066)          NaN
#
# [2000 rows x 9 columns]

# %% [markdown]
# ## Loading and merging nodes_filt with different sample sizes

# %%
#load new csv file and drop rows with NaN for 'avg_minutes' # not really set yet, 
nodes_filt_5000=pd.read_csv('nodes_{dt.datetime.now()}.csv', encoding = "latin")
nodes_filt_5000= nodes_filt_5000[nodes_filt_5000['avg_minutes'].isna()==False]

# %%
#merge datasets to enlarge the data for the map

# %%
#answering which nodes stands for 15-Minutes city
nodes_filt['15_minutes']=(nodes_filt['avg_minutes']<=15)
nodes_filt

#import datetime
import datetime as dt

#save data to csv
nodes_filt.to_csv(f'nodes_{dt.datetime.now()}.csv', index= False)
# Out:
# /Users/philinesophie/opt/anaconda3/lib/python3.8/site-packages/ipykernel/ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
#With Seaborn Plot Map for 'avg-minutes'

#plot whole map
ox.plot_graph(G, figsize=(10, 10), bgcolor='#666666', show=False, close=False)
# Point of Interest

sns.scatterplot(data=nodes_filt,x='x', y='y', hue= 'avg_minutes', palette='RdYlGn_r')
# Out:
# /Users/philinesophie/opt/anaconda3/lib/python3.8/site-packages/ipykernel/ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# <AxesSubplot:xlabel='x', ylabel='y'>

# %%
#With Seaborn Plot Map for '15_minutes'

#plot whole map
ox.plot_graph(G, figsize=(10, 10), show=False, close=False)
# Point of Interest

sns.scatterplot(data=nodes_filt,x='x', y='y', hue= '15_minutes', palette='RdYlGn_r')
# Out:
# /Users/philinesophie/opt/anaconda3/lib/python3.8/site-packages/ipykernel/ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# <AxesSubplot:xlabel='x', ylabel='y'>
